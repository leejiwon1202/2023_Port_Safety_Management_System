# %%
# !pip install ultralytics
# Out:
# ...
#                                               0.0/586.5 kB ? eta -:--:--
#      -------                                112.6/586.5 kB 2.2 MB/s eta 0:00:01
#      -----------------                      276.5/586.5 kB 3.4 MB/s eta 0:00:01
#      -----------------------                358.4/586.5 kB 3.2 MB/s eta 0:00:01
#      -------------------------------------- 586.5/586.5 kB 3.4 MB/s eta 0:00:00
# ...
#                                               0.0/1.2 MB ? eta -:--:--
#      --                                       0.1/1.2 MB 4.5 MB/s eta 0:00:01
#      --                                       0.1/1.2 MB 4.5 MB/s eta 0:00:01
#      ---------                                0.3/1.2 MB 2.1 MB/s eta 0:00:01
#      -------------------                      0.6/1.2 MB 3.3 MB/s eta 0:00:01
#      ----------------------                   0.7/1.2 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------        1.0/1.2 MB 3.5 MB/s eta 0:00:01
# ...

# %%
import ultralytics

# %%
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.106  Python-3.8.16 torch-2.0.1+cpu CPU
# Setup complete  (8 CPUs, 15.8 GB RAM, 300.4/756.8 GB disk)

# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n.pt')

# %%
model.train(data='E:/DataSets/Harbor_Data/Harbor_Data.yaml', epochs=2)
# Out:
# Ultralytics YOLOv8.0.106  Python-3.8.16 torch-2.0.1+cpu CPU
# ...

# %%
results = model.predict(source = "E:/DataSets/Harbor_Data/test/images/", save=True)
